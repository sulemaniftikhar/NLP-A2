# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import re
import unicodedata

# Load dataset
data_path = '/kaggle/input/urdu-dataset-20000/final_main_dataset.tsv'
df = pd.read_csv(data_path, sep='\t')  # Tab separator, adjust if needed
print("Columns in dataset:", df.columns.tolist())  # Columns check karo
# Out:
# Columns in dataset: ['client_id', 'path', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accents', 'variant', 'locale', 'segment']

# %%
# Install necessary libraries if needed (uncomment in Kaggle)
# !pip install urduhack  # For better Urdu tokenization, optional

import pandas as pd
import re
import unicodedata
from collections import Counter
import torch
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from sklearn.model_selection import train_test_split
import numpy as np

# Normalization function for Urdu
def normalize_urdu(text):
    # Remove diacritics
    text = ''.join(c for c in unicodedata.normalize('NFD', text) if unicodedata.category(c) != 'Mn')
    # Standardize Alef and Yeh forms
    text = re.sub(r'[آأإ]', 'ا', text)
    text = re.sub(r'[ےۓ]', 'ی', text)
    text = text.strip()
    return text

# Tokenization (simple word split; for better, use urduhack.tokenization.word_tokenize if installed)
def tokenize(text):
    return text.split()  # Or import urduhack and use urduhack.tokenization.word_tokenize(text)

# Load dataset
data_path = '/kaggle/input/urdu-dataset-20000/final_main_dataset.tsv'
df = pd.read_csv(data_path, sep='\t')  # Tab separator, adjust if needed
print("Columns in dataset:", df.columns.tolist())  # Confirm columns

# Clean column names
df.columns = df.columns.str.strip()

# Use 'sentence' as input, create synthetic 'Bot' response (e.g., add "جی ہاں" or rephrase)
df['User'] = df['sentence'].apply(normalize_urdu)
df['Bot'] = df['sentence'].apply(lambda x: normalize_urdu(x) + " - جی ہاں، بالکل!")  # Synthetic response

# Build vocabulary from all text
all_text = ' '.join(df['User'].tolist() + df['Bot'].tolist())
tokens = tokenize(all_text)
vocab_counter = Counter(tokens)
vocab = {word: idx + 4 for idx, (word, _) in enumerate(vocab_counter.most_common())}  # Start from 4 for special tokens
vocab['<PAD>'] = 0
vocab['<SOS>'] = 1
vocab['<EOS>'] = 2
vocab['<UNK>'] = 3
vocab_size = len(vocab)

# Reverse vocab for decoding
idx_to_word = {idx: word for word, idx in vocab.items()}

# Function to convert text to indices
def text_to_indices(text, vocab):
    tokens = tokenize(text)
    return [vocab.get(token, vocab['<UNK>']) for token in tokens]

# Add SOS/EOS and convert to tensors
df['user_indices'] = df['User'].apply(lambda x: [vocab['<SOS>']] + text_to_indices(x, vocab) + [vocab['<EOS>']])
df['bot_indices'] = df['Bot'].apply(lambda x: [vocab['<SOS>']] + text_to_indices(x, vocab) + [vocab['<EOS>']])

# Split dataset: 80% train, 10% val, 10% test
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Custom Dataset class
class ChatDataset(Dataset):
    def __init__(self, df):
        self.src = df['user_indices'].tolist()
        self.tgt = df['bot_indices'].tolist()
    
    def __len__(self):
        return len(self.src)
    
    def __getitem__(self, idx):
        return torch.tensor(self.src[idx]), torch.tensor(self.tgt[idx])

# Collate function for padding
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)
    src_padded = pad_sequence(src_batch, batch_first=True, padding_value=vocab['<PAD>'])
    tgt_padded = pad_sequence(tgt_batch, batch_first=True, padding_value=vocab['<PAD>'])
    return src_padded, tgt_padded

# Create datasets and loaders
batch_size = 32
train_dataset = ChatDataset(train_df)
val_dataset = ChatDataset(val_df)
test_dataset = ChatDataset(test_df)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

print("Data preprocessing complete. Vocab size:", vocab_size)
# Out:
# Columns in dataset: ['client_id', 'path', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accents', 'variant', 'locale', 'segment']
# Data preprocessing complete. Vocab size: 10860

# %%
import torch
import torch.nn as nn
import math

# Positional Encoding
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=1000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# Multi-Head Attention
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)
        self.w_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, q, k, v, mask=None):
        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(self.d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)
        attn = torch.softmax(scores, dim=-1)
        return torch.matmul(attn, v), attn

    def forward(self, q, k, v, mask=None):
        batch_size = q.size(0)
        q = self.w_q(q).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)
        k = self.w_k(k).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)
        v = self.w_v(v).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)
        output, attn = self.scaled_dot_product_attention(q, k, v, mask)
        output = output.transpose(1, 2).contiguous().view(batch_size, -1, self.d_model)
        return self.w_o(output)

# Feed Forward Network
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=1024, dropout=0.1):
        super().__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.linear2(self.dropout(torch.relu(self.linear1(x))))

# Encoder Layer
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, dropout=0.1):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.ff = FeedForward(d_model)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, src_mask):
        attn_output = self.self_attn(x, x, x, src_mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.ff(x)
        return self.norm2(x + self.dropout(ff_output))

# Decoder Layer
class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, dropout=0.1):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.enc_dec_attn = MultiHeadAttention(d_model, num_heads)
        self.ff = FeedForward(d_model)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        self_attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(self_attn_output))
        enc_dec_output = self.enc_dec_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(enc_dec_output))
        ff_output = self.ff(x)
        return self.norm3(x + self.dropout(ff_output))

# Full Transformer
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model=256, num_heads=2, num_layers=2, dropout=0.1, max_len=1000):
        super().__init__()
        self.src_embed = nn.Embedding(src_vocab_size, d_model)
        self.tgt_embed = nn.Embedding(tgt_vocab_size, d_model)
        self.pos_enc = PositionalEncoding(d_model, max_len)
        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, dropout) for _ in range(num_layers)])
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt, pad_idx=0):
        src_mask = (src != pad_idx).unsqueeze(1).unsqueeze(2)
        tgt_mask = (tgt != pad_idx).unsqueeze(1).unsqueeze(3)
        seq_len = tgt.size(1)
        nopeak_mask = torch.tril(torch.ones(seq_len, seq_len)).bool().to(tgt.device)
        tgt_mask = tgt_mask & nopeak_mask.unsqueeze(0).unsqueeze(0)
        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embed = self.dropout(self.pos_enc(self.src_embed(src)))
        tgt_embed = self.dropout(self.pos_enc(self.tgt_embed(tgt)))
        
        enc_output = src_embed
        for layer in self.encoder_layers:
            enc_output = layer(enc_output, src_mask)
        
        dec_output = tgt_embed
        for layer in self.decoder_layers:
            dec_output = layer(dec_output, enc_output, src_mask, tgt_mask)
        
        return self.fc_out(dec_output)

print("Model architecture defined.")
# Out:
# Model architecture defined.

# %%
# Install required packages
# !pip install sacrebleu
# !pip install rouge-score

import torch
import torch.nn as nn
import torch.optim as optim
import sacrebleu
from rouge_score import rouge_scorer
from tqdm import tqdm
import numpy as np
from torch.utils.data import DataLoader

# Set environment variable for better memory management
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Assuming ChatDataset and collate_fn are defined in Cell 1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Custom Tokenizer for Urdu (space-based splitting)
class UrduTokenizer:
    def tokenize(self, text):
        return text.split()

# Evaluation functions
def calculate_bleu(model, loader, idx_to_word):
    model.eval()
    references = []
    hypotheses = []
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            output = output.argmax(dim=-1).cpu().numpy()
            for i in range(output.shape[0]):
                hyp = ' '.join([idx_to_word.get(idx, '<UNK>') for idx in output[i] if idx not in [0, 1, 2]])
                ref = ' '.join([idx_to_word.get(idx, '<UNK>') for idx in tgt[i, 1:].cpu().numpy() if idx not in [0, 1, 2]])
                if hyp and ref:
                    hypotheses.append(hyp.strip())
                    references.append([ref.strip()])
    return sacrebleu.corpus_bleu(hypotheses, references).score if hypotheses and references else 0.0

def calculate_rouge(model, loader, idx_to_word):
    model.eval()
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=False, tokenizer=UrduTokenizer())  # Use custom Urdu tokenizer
    rouge_scores = []
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            output = output.argmax(dim=-1).cpu().numpy()
            for i in range(output.shape[0]):
                hyp = ' '.join([idx_to_word.get(idx, '') for idx in output[i] if idx not in [0, 1, 2]])  # Remove <UNK>
                ref = ' '.join([idx_to_word.get(idx, '') for idx in tgt[i, 1:].cpu().numpy() if idx not in [0, 1, 2]])
                if hyp and ref:
                    hyp = hyp.strip()
                    ref = ref.strip()
                    score = scorer.score(ref, hyp)['rougeL'].fmeasure
                    rouge_scores.append(score)
                    print(f"Debug - Hyp: '{hyp}', Ref: '{ref}', ROUGE-L: {score}")
    return np.mean(rouge_scores) if rouge_scores else 0.0

def calculate_chrf(model, loader, idx_to_word):
    model.eval()
    references = []
    hypotheses = []
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            output = output.argmax(dim=-1).cpu().numpy()
            for i in range(output.shape[0]):
                hyp = ' '.join([idx_to_word.get(idx, '<UNK>') for idx in output[i] if idx not in [0, 1, 2]])
                ref = ' '.join([idx_to_word.get(idx, '<UNK>') for idx in tgt[i, 1:].cpu().numpy() if idx not in [0, 1, 2]])
                if hyp and ref:
                    hypotheses.append(hyp.strip())
                    references.append([ref.strip()])
    return sacrebleu.corpus_chrf(hypotheses, references).score if hypotheses and references else 0.0

def calculate_perplexity(model, loader):
    model.eval()
    total_loss = 0
    total_words = 0
    criterion = nn.CrossEntropyLoss(ignore_index=vocab['<PAD>'], reduction='sum')
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = criterion(output.view(-1, vocab_size), tgt[:, 1:].reshape(-1))
            total_loss += loss.item()
            total_words += tgt[:, 1:].ne(vocab['<PAD>']).sum().item()
    avg_loss = total_loss / total_words if total_words > 0 else 0
    return np.exp(avg_loss) if avg_loss > 0 else float('inf')

def calculate_val_loss(model, loader):
    model.eval()
    val_loss = 0
    criterion = nn.CrossEntropyLoss(ignore_index=vocab['<PAD>'], reduction='sum')
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = criterion(output.view(-1, vocab_size), tgt[:, 1:].reshape(-1))
            val_loss += loss.item()
    return val_loss / len(loader)

# Trials configuration
trials = [
    {
        'embedding_dimensions': 256,
        'heads': 2,
        'encoder_layers': 2,
        'decoder_layers': 2,
        'dropout': 0.1,
        'batch_size': 32,
        'learning_rate': 1e-4,
        'model_path': 'temp_model_trial1.pth'
    },
    {
        'embedding_dimensions': 512,
        'heads': 2,
        'encoder_layers': 2,
        'decoder_layers': 2,
        'dropout': 0.3,
        'batch_size': 32,
        'learning_rate': 5e-4,
        'model_path': 'temp_model_trial2.pth'
    }
]

epochs = 20  # Adjust based on time/resources
best_overall_bleu = 0
best_model_state = None
best_trial_config = None

# Run trials
for trial_idx, trial in enumerate(trials, 1):
    print(f"\n=== Starting Trial {trial_idx} ===")
    print(f"Hyperparameters: Embedding Dimensions={trial['embedding_dimensions']}, Heads={trial['heads']}, Encoder Layers={trial['encoder_layers']}, "
          f"Decoder Layers={trial['decoder_layers']}, Dropout={trial['dropout']}, Batch Size={trial['batch_size']}, Learning Rate={trial['learning_rate']}")

    # Reinitialize model for each trial
    model = Transformer(src_vocab_size=10860, tgt_vocab_size=10860, 
                       d_model=trial['embedding_dimensions'], num_heads=trial['heads'], 
                       num_layers=trial['encoder_layers'], dropout=trial['dropout'])
    model.to(device)

    # Reinitialize DataLoader for the trial's batch size
    train_loader = DataLoader(train_dataset, batch_size=trial['batch_size'], shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=trial['batch_size'], shuffle=False, collate_fn=collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=trial['batch_size'], shuffle=False, collate_fn=collate_fn)

    optimizer = optim.Adam(model.parameters(), lr=trial['learning_rate'])
    criterion = nn.CrossEntropyLoss(ignore_index=vocab['<PAD>'])

    # Training loop
    best_trial_bleu = 0
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for src, tgt in tqdm(train_loader, desc=f"Trial {trial_idx} - Epoch {epoch+1}/{epochs}"):
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])  # Teacher forcing
            loss = criterion(output.view(-1, vocab_size), tgt[:, 1:].reshape(-1))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        # Validation
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for src, tgt in val_loader:
                src, tgt = src.to(device), tgt.to(device)
                output = model(src, tgt[:, :-1])
                loss = criterion(output.view(-1, vocab_size), tgt[:, 1:].reshape(-1))
                val_loss += loss.item()
        val_loss = val_loss / len(val_loader)
        
        val_bleu = calculate_bleu(model, val_loader, idx_to_word)
        print(f"Epoch {epoch+1}/{epochs}: Train Loss = {train_loss / len(train_loader):.4f}, Val Loss = {val_loss:.4f}, Val BLEU = {val_bleu:.2f}")
        
        if val_bleu > best_trial_bleu:
            best_trial_bleu = val_bleu
            torch.save(model.state_dict(), trial['model_path'])
            print(f"Saved best model for Trial {trial_idx} with BLEU: {best_trial_bleu:.2f}")

    # Final evaluation on test set for this trial
    model.load_state_dict(torch.load(trial['model_path']))
    test_bleu = calculate_bleu(model, test_loader, idx_to_word)
    test_rouge = calculate_rouge(model, test_loader, idx_to_word)
    test_chrf = calculate_chrf(model, test_loader, idx_to_word)
    test_perplexity = calculate_perplexity(model, test_loader)
    test_val_loss = calculate_val_loss(model, val_loader)

    print(f"\nTrial {trial_idx} Final Evaluation on Test Set:")
    print(f"BLEU: {test_bleu:.2f}, ROUGE-L: {test_rouge:.2f}, chrF: {test_chrf:.2f}, Perplexity: {test_perplexity:.2f}, Val Loss: {test_val_loss:.4f}")

    # Update best overall model if this trial's best BLEU is higher
    if best_trial_bleu > best_overall_bleu:
        best_overall_bleu = best_trial_bleu
        best_model_state = torch.load(trial['model_path'])
        best_trial_config = trial
        print(f"New overall best BLEU: {best_overall_bleu:.2f} from Trial {trial_idx}")

# Save the overall best model
if best_model_state is not None:
    best_model = Transformer(src_vocab_size=10860, tgt_vocab_size=10860, 
                           d_model=best_trial_config['embedding_dimensions'], num_heads=best_trial_config['heads'], 
                           num_layers=best_trial_config['encoder_layers'], dropout=best_trial_config['dropout'])
    best_model.load_state_dict(best_model_state)
    best_model.to(device)
    torch.save(best_model.state_dict(), 'best_model.pth')
    print(f"\nFinal best model saved as 'best_model.pth' with BLEU: {best_overall_bleu:.2f} from Trial {best_trial_config}")

    # Final evaluation of the best model on test set
    test_bleu = calculate_bleu(best_model, test_loader, idx_to_word)
    test_rouge = calculate_rouge(best_model, test_loader, idx_to_word)
    test_chrf = calculate_chrf(best_model, test_loader, idx_to_word)
    test_perplexity = calculate_perplexity(best_model, test_loader)
    test_val_loss = calculate_val_loss(best_model, val_loader)
    print(f"\nBest Model Final Evaluation on Test Set:")
    print(f"BLEU: {test_bleu:.2f}, ROUGE-L: {test_rouge:.2f}, chrF: {test_chrf:.2f}, Perplexity: {test_perplexity:.2f}, Val Loss: {test_val_loss:.4f}")
    print(f"Best Model Hyperparameters: Embedding Dimensions={best_trial_config['embedding_dimensions']}, Heads={best_trial_config['heads']}, "
          f"Encoder Layers={best_trial_config['encoder_layers']}, Decoder Layers={best_trial_config['decoder_layers']}, "
          f"Dropout={best_trial_config['dropout']}, Batch Size={best_trial_config['batch_size']}, Learning Rate={best_trial_config['learning_rate']}")
else:
    print("No valid model trained. Check dataset or training setup.")

print("\n=== All Trials Completed ===")
# Out:
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.11/dist-packages (2.5.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2025.9.18)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.4.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->sacrebleu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->sacrebleu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->sacrebleu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->sacrebleu) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->sacrebleu) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->sacrebleu) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->sacrebleu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->sacrebleu) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->sacrebleu) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->sacrebleu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->sacrebleu) (2024.2.0)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2025.9.18)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rouge-score) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rouge-score) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->rouge-score) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->rouge-score) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->rouge-score) (2024.2.0)
#
# === Starting Trial 1 ===
# Hyperparameters: Embedding Dimensions=256, Heads=2, Encoder Layers=2, Decoder Layers=2, Dropout=0.1, Batch Size=32, Learning Rate=0.0001
# Trial 1 - Epoch 1/20: 100%|██████████| 500/500 [00:10<00:00, 45.64it/s]
# Epoch 1/20: Train Loss = 4.5795, Val Loss = 3.5432, Val BLEU = 24.03
# Saved best model for Trial 1 with BLEU: 24.03
# Trial 1 - Epoch 2/20: 100%|██████████| 500/500 [00:10<00:00, 49.10it/s]
# Epoch 2/20: Train Loss = 3.2077, Val Loss = 2.6394, Val BLEU = 24.90
# Saved best model for Trial 1 with BLEU: 24.90
# Trial 1 - Epoch 3/20: 100%|██████████| 500/500 [00:10<00:00, 49.05it/s]
# Epoch 3/20: Train Loss = 2.4918, Val Loss = 2.0400, Val BLEU = 25.57
# Saved best model for Trial 1 with BLEU: 25.57
# Trial 1 - Epoch 4/20: 100%|██████████| 500/500 [00:10<00:00, 48.35it/s]
# Epoch 4/20: Train Loss = 1.9757, Val Loss = 1.5959, Val BLEU = 23.26
# Trial 1 - Epoch 5/20: 100%|██████████| 500/500 [00:10<00:00, 48.26it/s]
# Epoch 5/20: Train Loss = 1.5830, Val Loss = 1.2876, Val BLEU = 20.33
# Trial 1 - Epoch 6/20: 100%|██████████| 500/500 [00:10<00:00, 47.14it/s]
# Epoch 6/20: Train Loss = 1.2703, Val Loss = 1.0472, Val BLEU = 24.90
# Trial 1 - Epoch 7/20: 100%|██████████| 500/500 [00:10<00:00, 46.97it/s]
# Epoch 7/20: Train Loss = 1.0226, Val Loss = 0.8593, Val BLEU = 27.03
# Saved best model for Trial 1 with BLEU: 27.03
# Trial 1 - Epoch 8/20: 100%|██████████| 500/500 [00:10<00:00, 47.31it/s]
# Epoch 8/20: Train Loss = 0.8227, Val Loss = 0.7248, Val BLEU = 27.03
# Trial 1 - Epoch 9/20: 100%|██████████| 500/500 [00:10<00:00, 47.99it/s]
# Epoch 9/20: Train Loss = 0.6602, Val Loss = 0.6171, Val BLEU = 41.33
# Saved best model for Trial 1 with BLEU: 41.33
# Trial 1 - Epoch 10/20: 100%|██████████| 500/500 [00:10<00:00, 47.75it/s]
# Epoch 10/20: Train Loss = 0.5350, Val Loss = 0.5235, Val BLEU = 28.48
# Trial 1 - Epoch 11/20: 100%|██████████| 500/500 [00:10<00:00, 48.29it/s]
# Epoch 11/20: Train Loss = 0.4275, Val Loss = 0.4516, Val BLEU = 42.00
# Saved best model for Trial 1 with BLEU: 42.00
# Trial 1 - Epoch 12/20: 100%|██████████| 500/500 [00:10<00:00, 48.05it/s]
# Epoch 12/20: Train Loss = 0.3433, Val Loss = 0.3889, Val BLEU = 41.33
# Trial 1 - Epoch 13/20: 100%|██████████| 500/500 [00:10<00:00, 47.54it/s]
# Epoch 13/20: Train Loss = 0.2754, Val Loss = 0.3491, Val BLEU = 42.00
# Trial 1 - Epoch 14/20: 100%|██████████| 500/500 [00:10<00:00, 47.32it/s]
# Epoch 14/20: Train Loss = 0.2208, Val Loss = 0.3131, Val BLEU = 41.33
# Trial 1 - Epoch 15/20: 100%|██████████| 500/500 [00:10<00:00, 47.80it/s]
# Epoch 15/20: Train Loss = 0.1816, Val Loss = 0.2951, Val BLEU = 41.33
# Trial 1 - Epoch 16/20: 100%|██████████| 500/500 [00:10<00:00, 48.07it/s]
# Epoch 16/20: Train Loss = 0.1485, Val Loss = 0.2692, Val BLEU = 42.00
# Trial 1 - Epoch 17/20: 100%|██████████| 500/500 [00:10<00:00, 48.21it/s]
# Epoch 17/20: Train Loss = 0.1228, Val Loss = 0.2566, Val BLEU = 42.00
# Trial 1 - Epoch 18/20: 100%|██████████| 500/500 [00:10<00:00, 47.68it/s]
# Epoch 18/20: Train Loss = 0.1010, Val Loss = 0.2514, Val BLEU = 42.00
# Trial 1 - Epoch 19/20: 100%|██████████| 500/500 [00:10<00:00, 47.87it/s]
# Epoch 19/20: Train Loss = 0.0813, Val Loss = 0.2220, Val BLEU = 41.17
# Trial 1 - Epoch 20/20: 100%|██████████| 500/500 [00:10<00:00, 47.70it/s]
# Epoch 20/20: Train Loss = 0.0660, Val Loss = 0.2243, Val BLEU = 39.81
# Debug - Hyp: 'ہر چیز انتہايی زبردست اور اعلی معیار کی تھی - جی ہاں، بالکل! - - - - - - - - -', Ref: 'ہر چیز انتہايی زبردست اور اعلی معیار کی تھی - جی ہاں، بالکل!', ROUGE-L: 0.7428571428571429
# Debug - Hyp: 'اس جمود کو ہیرو ہی۔ - جی ہاں، بالکل! - - - - - - - - - - - - -', Ref: 'اس جمود کو توڑا ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5161290322580644
# Debug - Hyp: 'انہوںنی ناریل کی چھلکی سی کاربن حاصل کرکی - جی ہاں، بالکل! جی - - - - - - - - -', Ref: 'انہوںنی ناریل کی چھلکی سی کاربن حاصل کرکی - جی ہاں، بالکل!', ROUGE-L: 0.7058823529411764
# Debug - Hyp: 'اسی پتہ بھی ہی کہ وہ جھوٹ بول رہا ہی - جی ہاں، بالکل! - - - - - - - -', Ref: 'اسی پتہ بھی ہی کہ وہ جھوٹ بول رہا ہی - جی ہاں، بالکل!', ROUGE-L: 0.7777777777777778
# Debug - Hyp: 'افسوس، یہ ہی۔ - جی ہاں، بالکل! - - - - جی جی جی - - - - - - - -', Ref: 'افسوس، یہ ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0
- جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'دنیايی قیمتوں قیمتوں زايد ٹینس کھلاڑیوں رہنی والی ڈیری کردیا نہیں۔ - جی ہاں، بالکل! - - - - - - -', Ref: 'مقررہ قیمتوں سی زايد نرخوں پردودھ بیچنی والی ڈیری فارمرز گرفتار - جی ہاں، بالکل!', ROUGE-L: 0.43243243243243246
# Debug - Hyp: 'اور پھر ایک ہیرو ہیرو کی ذریعہ ادمی میں شکست اداری ہی - جی ہاں، بالکل! - - - - - -', Ref: 'اور پھر ایک بہادر ہیرو کی ذریعہ ادمی میں شکست کھاتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.7368421052631579
# Debug - Hyp: 'نوکریاں مل نہیں رہیں۔ - جی ہاں، بالکل! - - - - جی - - - - - - - - -', Ref: 'نوکریاں مل نہیں رہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.5333333333333333
# Debug - Hyp: 'حد سی تجاوز بھی ہوتا ہی کہ انسان کا انعقاد یہی یہی - جی ہاں، بالکل! - - - - - -', Ref: 'حد سی تجاوز بھی ہوتا ہی کہ انسان کا وتیرہ یہی ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7368421052631579
# Debug - Hyp: 'دوسروں کی ساتھ اسانی سی کام کر سکتا ہوں - جی ہاں، بالکل! - - - - - - - - -', Ref: 'دوسروں کی ساتھ اسانی سی کام کر سکتا ہوں - جی ہاں، بالکل!', ROUGE-L: 0.7428571428571429
# Debug - Hyp: 'مگر ایرانی حکومت نی جس طرح اسی باہمی - جی ہاں، بالکل! جی جی - - - - - - - -', Ref: 'مگر ایرانی حکومت نی جس طرح اسی باہمی - جی ہاں، بالکل!', ROUGE-L: 0.7058823529411764
# Debug - Hyp: 'جمال ضروری کیا مت - جی ہاں، بالکل! - - - - - - - - - - - - - -', Ref: 'جمال خشوگی… کیا کہیں؟ - جی ہاں، بالکل!', ROUGE-L: 0.39999999999999997
# Debug - Hyp: 'گویا اسمان سی انی والی صدا اسی طرح جرمنی رہی گی۔ - جی ہاں، بالکل! - - - - - - -', Ref: 'گویا اسمان سی انی والی صدا اسی طرح گونجتی رہی گی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7567567567567568
# Debug - Hyp: 'لوگوں کو ٹھنڈا دینی کی لیی دیی دیی جا رہی ہیں۔ - جی ہاں، بالکل! - - - - - - -', Ref: 'لوگوں کو اذانیں دینی کی لیی پیسی دیی جا رہی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.7027027027027029
# Debug - Hyp: 'ایم این ایس زرعی - جی ہاں، بالکل! - - - - - - - - - - - - - -', Ref: 'ایم این ایس زرعی - جی ہاں، بالکل!', ROUGE-L: 0.5333333333333333
# Debug - Hyp: 'اس کی ساتھ بڑا گھر دولت کی اظہار کا ذریعہ بھی ہی۔ - جی ہاں، بالکل! - - - - - -', Ref: 'اس کی ساتھ بڑا گھر دولت کی اظہار کا ذریعہ بھی ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.8421052631578948
# Debug - Hyp: 'ايیی ان پر ایک نگاہ ڈالتی ہیں۔ - جی ہاں، بالکل! جی جی - - - - - - - - -', Ref: 'ايیی ان پر ایک نگاہ ڈالتی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'صدر مقام یروشلم کو کہا جاتا ہی - جی ہاں، بالکل! جی جی جی - - - - - - ہی -', Ref: 'صدر مقام یروشلم کو کہا جاتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'برازیل - جی ہاں، بالکل! جی - - - - - - - - - - - - - - - -', Ref: 'برازیل - جی ہاں، بالکل!', ROUGE-L: 0.37037037037037035
# Debug - Hyp: 'اس کہانی کو انصاف کرنی کی ليی اتنا وقت نہیں دیا جاتا ہی - جی ہاں، بالکل! - - - - - - - - - - -', Ref: 'اس کہانی کو انصاف کرنی کی ليی اتنا وقت نہیں دیا جاتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.7555555555555554
# Debug - Hyp: 'جو کا سبب پاکستان کرکٹ تنزلی کرنا گامزن ہونا ہونا - جی ہاں، بالکل! - - - - - - - - - - - - - -', Ref: 'جو کا سبب پاکستان کرکٹ تنزلی کرنا جانب گامزن ہونا - جی ہاں، بالکل!', ROUGE-L: 0.6190476190476191
# Debug - Hyp: 'بس گھنٹی ڈیڑھ کی مار ہی، - جی ہاں، بالکل! جی جی جی - - - - - - - - - - - - - - -', Ref: 'بس گھنٹی ڈیڑھ کی مار ہی، - جی ہاں، بالکل!', ROUGE-L: 0.5263157894736842
# Debug - Hyp: 'ايی سی سی سی روس ڈار کو بھارت میں میچ سی سی ہٹا دیا - جی ہاں، بالکل! - - - - - - - - - -', Ref: 'ايی سی سی نی علیم ڈار کو بھارت میں میچ امپايرنگ سی ہٹا دیا - جی ہاں، بالکل!', ROUGE-L: 0.6521739130434783
# Debug - Hyp: 'اور اس کی وضاحت اپ ہی کیليی ہیں - جی ہاں، بالکل! جی - - - - - - - - - - - - - - -', Ref: 'اور اس کی وضاحت اپ ہی کیليی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.6
# Debug - Hyp: 'کینیا کی دارلحکومت میں ربڑ اور پلاسٹک کی ڈھیر ڈھیر گرافر ایڈورڈ ہو کی تصاویر پہلی بار دکھنی میں معمولی ضرور ہیں اتی ہیں - جی ہاں، بالکل!', Ref: 'کینیا کی دارلحکومت میں ربڑ اور پلاسٹک کی ڈھیر فوٹو گرافر ایڈورڈ برٹینسکی کی تصاویر پہلی بار دکھنی میں معمولی ضرور نظر اتی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.8928571428571429
# Debug - Hyp: 'وہ فوج جس کا کام سرحدوں کی حفاظت ہی اس نی ملک میں بڑی بڑی کاروبار شروع کر رکھی ہیں - جی ہاں، بالکل! ہیں ہیں ہیں ہیں', Ref: 'وہ فوج جس کا کام سرحدوں کی حفاظت ہی اس نی ملک میں بڑی بڑی کاروبار شروع کر رکھی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.923076923076923
# Debug - Hyp: 'اسینشن ايلینڈ - جی ہاں، بالکل! - - - - - - - - - - - - - - - - - - - - - -', Ref: 'اسینشن ايلینڈ - جی ہاں، بالکل!', ROUGE-L: 0.35294117647058826
# Debug - Hyp: 'تو پہلی کرتی۔ - جی ہاں، بالکل! تو - - - - - - - - - - - - - - - - - - - -', Ref: 'تو پہلی کرتی۔ - جی ہاں، بالکل!', ROUGE-L: 0.4
# Debug - Hyp: 'دنیايی قیمتوں قیمتوں زايد ٹینس کھلاڑیوں رہنی والی ڈیری کردیا نہیں۔ - جی ہاں، بالکل! - - - - - - - - - - - - -', Ref: 'مقررہ قیمتوں سی زايد نرخوں پردودھ بیچنی والی ڈیری فارمرز گرفتار - جی ہاں، بالکل!', ROUGE-L: 0.37209302325581395
# Debug - Hyp: 'ورنہ دنیا میں کیا نہیں باقی - جی ہاں، بالکل! جی - - - - - - - - - - - - - - - - -', Ref: 'ورنہ دنیا میں کیا نہیں باقی - جی ہاں، بالکل!', ROUGE-L: 0.5263157894736842
# Debug - Hyp: 'لیکن وہ کیفیت ہم میں کہاں سی اتی؟ - جی ہاں، بالکل! جی - - - - - - - - - - - - - - -', Ref: 'لیکن وہ کیفیت ہم میں کہاں سی اتی؟ - جی ہاں، بالکل!', ROUGE-L: 0.6
# Debug - Hyp: 'بہت لوگ خان کی دوران غیر ملک میں چھٹی لی کر ہم ہیں۔ - جی ہاں، بالکل! - - - - - - - - - - -', Ref: 'بہت لوگ گرمیوں کی دوران غیر ملک میں چھٹی لی کر گھومتی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666667
# Debug - Hyp: 'اگر اپ دنیا کی مالی پر مشرق وسطی - جی ہاں، بالکل! جی - - - - - - - - - - - - - - -', Ref: 'اگر اپ دنیا کی نقشی پر مشرق وسطی - جی ہاں، بالکل!', ROUGE-L: 0.55
# Debug - Hyp: 'اللہ تعالی کی حسن و جمال کا کويی اندازہ نہیں لگا - - جی ہاں، بالکل! - - - - - - - - - - - -', Ref: 'اللہ تعالی کی حسن و جمال کا کويی اندازہ نہیں لگا سکت - جی ہاں، بالکل!', ROUGE-L: 0.6818181818181818
# Debug - Hyp: 'جب گاڑی نی ہماری منزل پر ا کر بریک لگايی - جی ہاں، بالکل! - - - - - - - - - - - - - -', Ref: 'جب گاڑی نی ہماری منزل پر ا کر بریک لگايی - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'بتوں کا تو باقاعدہ ذکر ہوا - جی ہاں، بالکل! جی - - - - - - - - - - - - - - - - -', Ref: 'بتوں کا تو باقاعدہ ذکر ہوا - جی ہاں، بالکل!', ROUGE-L: 0.5263157894736842
# Debug - Hyp: 'بہت ساری چیزوں کو بیک وقت کرنی کی صلاحیت رکھتا ہوں - جی ہاں، بالکل! - - - - - - - - - - - - -', Ref: 'بہت ساری چیزوں کو بیک وقت کرنی کی صلاحیت رکھتا ہوں - جی ہاں، بالکل!', ROUGE-L: 0.6976744186046512
# Debug - Hyp: 'اور ڈراموں کا بڑا نام ہیں - جی ہاں، بالکل! جی - - - - - - - - - - - - - - - - -', Ref: 'اور ڈراموں کا بڑا نام ہیں - جی ہاں، بالکل!', ROUGE-L: 0.5263157894736842
# Debug - Hyp: 'اس علاقہ میں گاڑی کی مابین لٹک خطر ضرور ہی - جی ہاں، بالکل! - - - - - - - - - - - - - -', Ref: 'اس علاقہ میں گاڑی کی پیچھ لٹک خطر ضرور ہی - جی ہاں، بالکل!', ROUGE-L: 0.6190476190476191
# Debug - Hyp: 'اپ کیا خاموشی گی - جی ہاں، بالکل! کیا - - - - - - - - - - - - - - - - - - -', Ref: 'اپ کیا پیو گی - جی ہاں، بالکل!', ROUGE-L: 0.3888888888888889
# Debug - Hyp: 'دیکھو یہاں بستر لگادو - جی ہاں، بالکل! - - - - - - - - - - - - - - - - - - - -', Ref: 'دیکھو یہاں بستر لگادو - جی ہاں، بالکل!', ROUGE-L: 0.4444444444444445
# Debug - Hyp: 'سوالات بہت سی ہیں۔ - جی ہاں، بالکل! جی - - - جی - - - - - - - - - - - - - - -', Ref: 'سوالات بہت سی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.4444444444444445
# Debug - Hyp: 'اور معاشی صورت حال اس عمر پر پہنچ - جی ہاں، بالکل! جی - - - - - - - - - - - - - - -', Ref: 'اور معاشی صورت حال اس نہج پر پہنچ - جی ہاں، بالکل!', ROUGE-L: 0.55
# Debug - Hyp: 'جس کی پہلی تین بیٹسمین پہلی اننگز میں اسکور پر لوٹ لوٹ گيی ۔ - جی ہاں، بالکل! - - - - - - - - - -', Ref: 'جس کی پہلی تین بیٹسمین پہلی اننگز میں اسکور پر پویلین لوٹ گيی ۔ - جی ہاں، بالکل!', ROUGE-L: 0.7391304347826088
# Debug - Hyp: 'لطافت کا حسین امتزاج دکھايی دیتا ہی - جی ہاں، بالکل! جی جی جی - - - - - - - - - - - - - -', Ref: 'لطافت کا حسین امتزاج دکھايی دیتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.5641025641025641
# Debug - Hyp: 'کری ‘ ہماری بلا سی۔ - جی ہاں، بالکل! - - - - - - - - - - - - - - - - - - -', Ref: 'کری ‘ ہماری بلا سی۔ - جی ہاں، بالکل!', ROUGE-L: 0.4864864864864865
# Debug - Hyp: 'تو دنیايی اسلام میں۔ - جی ہاں، بالکل! - - - - - - - - - - - - - - - - - - - -', Ref: 'تو دنیايی اسلام میں۔ - جی ہاں، بالکل!', ROUGE-L: 0.4444444444444445
# Debug - Hyp: 'اپ ان کو یہ کھلا کھلا کون اپ کا ہاتھ پکڑ رہا ہی؟ - جی ہاں، بالکل! - - - - - - - - - - -', Ref: 'اپ ان کو یہ سہولت دیں، کون اپ کا ہاتھ پکڑ رہا ہی؟ - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666667
# Debug - Hyp: 'اپنی انکھوں کی کی طرف بڑھتی ہويی - - جی ہاں، بالکل! جی - - - - - - - - - - - - - - -', Ref: 'اپنی چالیسویں سالگرہ کی طرف بڑھتی ہويی ک - جی ہاں، بالکل!', ROUGE-L: 0.45000000000000007
# Debug - Hyp: '- - جی ہاں، بالکل! - - - - - - - - - - - - - - - - - - - - - - -', Ref: 'جارجیا - جی ہاں، بالکل!', ROUGE-L: 0.24242424242424243
# Debug - Hyp: 'شو کی دوران کرن کرن نی شویتا سی کہا - جی ہاں، بالکل! - - - - - - - - - - - - - - -', Ref: 'شو کی دوران کرن جوہر نی شویتا سی کہا - جی ہاں، بالکل!', ROUGE-L: 0.5853658536585366
# Debug - Hyp: 'پیر کی وجود سی ریاست قايم ہی۔ - جی ہاں، بالکل! جی جی - - - - - - - - - -', Ref: 'اوراسی کی وجود سی ریاست قايم ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5882352941176471
# Debug - Hyp: 'کہیں تو بہر خدا اج ذکر یار چلی - جی ہاں، بالکل! جی جی - - - - - - - - -', Ref: 'کہیں تو بہر خدا اج ذکر یار چلی - جی ہاں، بالکل!', ROUGE-L: 0.6857142857142856
# Debug - Hyp: 'نواز شریف کرکٹ بورڈ میں تباہی کی ذمہ داری قبول کریں عمران خان - جی ہاں، بالکل! - - - - - -', Ref: 'نواز شریف کرکٹ بورڈ میں تباہی کی ذمہ داری قبول کریں عمران خان - جی ہاں، بالکل!', ROUGE-L: 0.85
# Debug - Hyp: 'بلکہ ہماری اپنی بہتری اسی میں ہی۔ - جی ہاں، بالکل! جی جی جی - - - - - - - - -', Ref: 'بلکہ ہماری اپنی بہتری اسی میں ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.6470588235294118
# Debug - Hyp: 'ڈاکٹر طور پر بھی متاثر ہويیں اور - جی ہاں، بالکل! جی جی - - - - - - - - - -', Ref: 'جسمانی طور پر بھی متاثر ہويیں اور - جی ہاں، بالکل!', ROUGE-L: 0.5882352941176471
# Debug - Hyp: 'تمام غیر شاعر حالات - جی ہاں، بالکل! - - - - - - - - - - - - - - -', Ref: 'تمام غیر موافق حالات - جی ہاں، بالکل!', ROUGE-L: 0.4516129032258065
# Debug - Hyp: 'پہنچ کر سوچا اس پر کچھ لکھتی ہیں - جی ہاں، بالکل! جی جی - - - - - - - - -', Ref: 'پہنچ کر سوچا اس پر کچھ لکھتی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.6857142857142856
# Debug - Hyp: 'یکساں کپتان کی موجودگی سی - جی ہاں، بالکل! - جی جی - - - - - - - - - - -', Ref: 'یکساں کپتان کی موجودگی سی - جی ہاں، بالکل!', ROUGE-L: 0.5625
# Debug - Hyp: 'بی پیر کا رونا فضول بات ہی۔ - جی ہاں، بالکل! جی جی - - - - - - - - - -', Ref: 'بی حیايی کا رونا فضول بات ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5882352941176471
# Debug - Hyp: 'اج انتخابات ہوں۔ - جی ہاں، بالکل! - - - - جی جی جی - - - - - - - - -', Ref: 'اج انتخابات ہوں۔ - جی ہاں، بالکل!', ROUGE-L: 0.4666666666666667
# Debug - Hyp: 'سات لاکھ کی فوج ہی اور ہم ایک ایٹمی قوت بھی ہیں۔ - جی ہاں، بالکل! - - - - - - -', Ref: 'سات لاکھ کی فوج ہی اور ہم ایک ایٹمی قوت بھی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.8205128205128205
# Debug - Hyp: 'جہاں باپ اور بھايیوں کو ٹیسٹ چڑھا دیا جاتا ہی۔ - جی ہاں، بالکل! - - - - - - - - -', Ref: 'جہاں باپ اور بھايیوں کو بھینٹ چڑھا دیا جاتا ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7027027027027025
# Debug - Hyp: 'یہ اعتماد پیدا کرتا ہی - جی ہاں، بالکل! جی - - - - - - - - - - - - -', Ref: 'یہ اعتماد پیدا کرتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.5625
# Debug - Hyp: 'ہماری ہر حکومت اہل مذہب کی خوف میں مبتلا رہی ہی۔ - جی ہاں، بالکل! - - - - - - - -', Ref: 'ہماری ہر حکومت اہل مذہب کی خوف میں مبتلا رہی ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7894736842105263
# Debug - Hyp: 'مجھ سی سوال کیی جاتی ہیں مجھی نہیں اتی - جی ہاں، بالکل! جی - - - - - - - - -', Ref: 'مجھ سی سوال کیی جاتی ہیں مجھی نہیں اتی - جی ہاں، بالکل!', ROUGE-L: 0.7222222222222222
# Debug - Hyp: 'مشرقی کا جادو کی ذریعی حسن حسن کو نقصان تحسین - جی ہاں، بالکل! - - - - - - - - -', Ref: 'گوگل کا ڈوڈل کی ذریعی نازیہ حسن کو خراج تحسین - جی ہاں، بالکل!', ROUGE-L: 0.5405405405405405
# Debug - Hyp: 'جس کو چاہتا ملازمت سی ہٹا دیتا - جی ہاں، بالکل! جی - - - - - - - - - - -', Ref: 'جس کو چاہتا ملازمت سی ہٹا دیتا - جی ہاں، بالکل!', ROUGE-L: 0.6470588235294118
# Debug - Hyp: 'دل میں بکھری کويی خوشبويی صبا اخر شب - جی ہاں، بالکل! جی جی - - - - - - - - -', Ref: 'دل میں بکھری کويی خوشبويی قبا اخر شب - جی ہاں، بالکل!', ROUGE-L: 0.6285714285714286
# Debug - Hyp: 'اداکاروں کی پاس وقت نہیں ہوتا ہی - جی ہاں، بالکل! جی جی جی - - - - - - - - -', Ref: 'اداکاروں کی پاس وقت نہیں ہوتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.6470588235294118
# Debug - Hyp: 'بلکہ اس کی اگر ضرورت پیش ايی تو - جی ہاں، بالکل! جی جی - - - - - - - - -', Ref: 'بلکہ اس کی اگر ضرورت پیش ايی تو - جی ہاں، بالکل!', ROUGE-L: 0.6857142857142856
# Debug - Hyp: 'تو طالبان کیسی غلط کر رہی تھی؟ - جی ہاں، بالکل! جی جی - - - - - - - - - -', Ref: 'تو طالبان کیسی غلط کر رہی تھی؟ - جی ہاں، بالکل!', ROUGE-L: 0.6470588235294118
# Debug - Hyp: 'دوسروں کی پوشیدہ مقاصد پر شکرمیں رہتا ہوں - جی ہاں، بالکل! جی جی - - - - - - - - -', Ref: 'دوسروں کی پوشیدہ مقاصد پر شکرمیں رہتا ہوں - جی ہاں، بالکل!', ROUGE-L: 0.6857142857142856
# Debug - Hyp: 'عثمان بزدار پہ صحیح تنقید ہوتی ہی۔ - جی ہاں، بالکل! جی جی - - - - - - - - - -', Ref: 'عثمان بزدار پہ صحیح تنقید ہوتی ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.6470588235294118
# Debug - Hyp: 'میڈیا پر بات نہیں کی لیکن - جی ہاں، بالکل! جی - - - - - - - - - - - -', Ref: 'میڈیا پر بات نہیں کی لیکن - جی ہاں، بالکل!', ROUGE-L: 0.6060606060606061
# Debug - Hyp: 'گھر جو چراغ تھا سر شام وہ کیسی کیسی - جی ہاں، بالکل! - - - - - - - - - -', Ref: 'گھر جو ویراں تھا سر شام وہ کیسی کیسی - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666667
# Debug - Hyp: 'ہت تیری مناتی - جی ہاں، بالکل! - - - - جی جی جی - - - - - - - - -', Ref: 'ہت تیری کی! - جی ہاں، بالکل!', ROUGE-L: 0.4
# Debug - Hyp: 'کی خلاف ایک سازش ہی۔ - جی ہاں، بالکل! جی - - - - - - - - - - - - -', Ref: 'کی خلاف ایک سازش ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5625
# Debug - Hyp: 'کیونکہ قومی ٹیم کی خامیاں جنوبی افریقہ اور سری لنکا کی خلاف مصیبتوں کا پھندہ بن سکتی ہیں ۔ - جی ہاں، بالکل!', Ref: 'کیونکہ قومی ٹیم کی خامیاں جنوبی افریقہ اور سری لنکا کی خلاف مصیبتوں کا پھندہ بن سکتی ہیں ۔ - جی ہاں، بالکل!', ROUGE-L: 1.0
# Debug - Hyp: 'میٹھی املیٹ کی خدوخال اور پکانی کی ترکیب پر روشنی ڈالی - جی ہاں، بالکل! - - - - - - - -', Ref: 'میٹھی املیٹ کی خدوخال اور پکانی کی ترکیب پر روشنی ڈالی - جی ہاں، بالکل!', ROUGE-L: 0.7894736842105263
# Debug - Hyp: 'ہا پیغام لینی ہی کل تھوڑی سی دیر ہو جايی گی۔ - جی ہاں، بالکل! - - - - - - - -', Ref: 'ہا بہايی لینی ہی کلاس۔۔۔ تھوڑی سی دیر ہو جايی گی۔ - جی ہاں، بالکل!', ROUGE-L: 0.6842105263157895
# Debug - Hyp: 'دوسروں کی مسايل میں دلچسپی نہیں لیتا - جی ہاں، بالکل! جی جی جی - - - - - - - - -', Ref: 'دوسروں کی مسايل میں دلچسپی نہیں لیتا - جی ہاں، بالکل!', ROUGE-L: 0.6470588235294118
# Debug - Hyp: 'اسٹیٹ بینک کی پالیسی پالیسی کا اعلان اج ہوگا - جی ہاں، بالکل! جی - - - - - - - - -', Ref: 'اسٹیٹ بینک کی مانیٹری پالیسی کا اعلان اج ہوگا - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666667
# Debug - Hyp: 'کہہ رہی ہیں۔ - جی ہاں، بالکل! رہی - - - - جی جی - - - - - - - - - -', Ref: 'کہہ رہی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.45161290322580644
# Debug - Hyp: 'ایران کی ٹیم فیفاورلڈ کپ کپ لاک کا پھر بھی جشن - جی ہاں، بالکل! - - - - - - - - -', Ref: 'ایران کی ٹیم فیفاورلڈ کپ سی باہرمداحوں کا پھر بھی جشن - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666667
# Debug - Hyp: 'یہ کوہ چلتن تو بہت سی جنگلی جانوروں سی بھرا پڑا ہی - جی ہاں، بالکل! - - - - - - - -', Ref: 'یہ کوہ چلتن تو بہت سی جنگلی جانوروں سی بھرا پڑا ہی - جی ہاں، بالکل!', ROUGE-L: 0.8
# Debug - Hyp: 'اب ایسا نہیں۔ - جی ہاں، بالکل! اب - جی جی جی جی جی جی - - - - - - - - -', Ref: 'اب ایسا نہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.45161290322580644
# Debug - Hyp: 'دوسروں کی منصوبوں میں رکاوٹ بنتا ہوں - جی ہاں، بالکل! جی جی - - - - - - - - - - -', Ref: 'دوسروں کی منصوبوں میں رکاوٹ بنتا ہوں - جی ہاں، بالکل!', ROUGE-L: 0.6285714285714286
# Debug - Hyp: 'مجھی کھلی پیسی دیں۔ - جی ہاں، بالکل! جی - - - جی - - - - - - - - - - -', Ref: 'مجھی کھلی پیسی دیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 'اس جدید دور میں مختلف مختلف طرح کی روبوٹس تیار کر رہی ہیں - جی ہاں، بالکل! - ہیں ہیں - - ہیں ہیں', Ref: 'اس جدید دور میں صنعتکار مختلف طرح کی روبوٹس تیار کر رہی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.7804878048780487
# Debug - Hyp: 'یہ چینی تھی۔ - جی ہاں، بالکل! یہ - - - جی جی جی - - - - - - - - - -', Ref: 'یہ چینی تھی۔ - جی ہاں، بالکل!', ROUGE-L: 0.45161290322580644
# Debug - Hyp: 'اگر یہی صورتحال ہی۔ - جی ہاں، بالکل! یہی جی جی جی جی جی - - - - - - - - - -', Ref: 'اگر یہی صورتحال ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 'اب تو ہاتھ دراصل نہ قانون لیکن اب سی پہلی تو - جی ہاں، بالکل! - - - - - - - - -', Ref: 'اب تو ہاتھ سجھايی نہ دیوی لیکن اب سی پہلی تو - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666667
# Debug - Hyp: 'اسی اعتبار سی اسی قبول کرتی ہیں - جی ہاں، بالکل! جی جی جی - - - - - - - - - -', Ref: 'اسی اعتبار سی اسی قبول کرتی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.6285714285714286
# Debug - Hyp: 'پاکستان سی محبت - جی ہاں، بالکل! - - - جی جی جی جی - - - - - - - - - -', Ref: 'پاکستان سی محبت - جی ہاں، بالکل!', ROUGE-L: 0.45161290322580644
# Debug - Hyp: '، اور جیسا اسلام چیمپين ویسا گی اختلاف پڑی گا - جی ہاں، بالکل! - - - - - - - - - -', Ref: '، اور جیسا بويیں گی ویسا ہی کاٹنا پڑی گا - جی ہاں، بالکل!', ROUGE-L: 0.5263157894736842
# Debug - Hyp: 'تو ثانوی حیثیت کی شہریوں کی طرح۔ - جی ہاں، بالکل! جی جی - - - - - - - - - - -', Ref: 'تو ثانوی حیثیت کی شہریوں کی طرح۔ - جی ہاں، بالکل!', ROUGE-L: 0.6285714285714286
# Debug - Hyp: 'یہ ان کی لیی ملازمت کا معاملہ نہیں، ایک مشن تھا۔ - جی ہاں، بالکل! - - - - - - - - -', Ref: 'یہ ان کی لیی ملازمت کا معاملہ نہیں، ایک مشن تھا۔ - جی ہاں، بالکل!', ROUGE-L: 0.7692307692307693
# Debug - Hyp: 'فلم نی پہلی ویک - جی ہاں، بالکل! نی - - - - - - - - - - - - - - -', Ref: 'فلم نی پہلی ویک - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 
ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7692307692307693
# Debug - Hyp: 'اس سی ماحولیاتی تحفظ میں مددملی گی ۔ - جی ہاں، بالکل! جی - - - - - - - - - - -', Ref: 'اس سی ماحولیاتی تحفظ میں مددملی گی ۔ - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'ایک سال سی کچھ پہلی کھلنی والی - جی ہاں، بالکل! جی جی جی - - - - - - - - - -', Ref: 'ایک سال سی کچھ پہلی کھلنی والی - جی ہاں، بالکل!', ROUGE-L: 0.6285714285714286
# Debug - Hyp: 'باہمی روابط تعصب کی شدت کو کم کر دیتی ہیں - جی ہاں، بالکل! - - - - - - - - - -', Ref: 'باہمی روابط تعصب کی شدت کو کم کر دیتی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.7368421052631579
# Debug - Hyp: 'مریضوں کی لحاظ سی یہ نومبر کی لیی پناہ کی تھی - جی ہاں، بالکل! - - - - - - - - -', Ref: 'حجم کی لحاظ سی یہ نومبر کی لیی منحوس شروعات تھی - جی ہاں، بالکل!', ROUGE-L: 0.6153846153846154
# Debug - Hyp: '، درپیش تا ہی تو بربادی کا ٹکٹ پیدا کرتا ہی ۔ - جی ہاں، بالکل! - - - - - - - -', Ref: '، بپھر تا ہی تو بربادی کا ساماں پیدا کرتا ہی ۔ - جی ہاں، بالکل!', ROUGE-L: 0.7000000000000001
# Debug - Hyp: 'یہ تو کل کی بات ہی۔ - جی ہاں، بالکل! جی جی جی - - - - - - - -', Ref: 'یہ تو کل کی بات ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.6451612903225806
# Debug - Hyp: 'قدرت کتنی خوب صورت ہی - جی ہاں، بالکل! جی جی جی جی - - - - - - - -', Ref: 'قدرت کتنی خوب صورت ہی - جی ہاں، بالکل!', ROUGE-L: 0.6
# Debug - Hyp: 'اور وہ تم پر اپنی بہت مقرر رکھتا ہی - جی ہاں، بالکل! - - - - - - - -', Ref: 'اور وہ تم پر اپنی نگران مقرر رکھتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.7058823529411765
# Debug - Hyp: 'سابق کپتان مصباح الحق نی دوستوں لی لیا - جی ہاں، بالکل! جی - - - - - - - -', Ref: 'سابق کپتان مصباح الحق نی یوٹرن لی لیا - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666667
# Debug - Hyp: 'اب دیکھنی گیمز کرتا کی جماعتوں میں شامل ہو رہی ہیں - جی ہاں، بالکل! - - - - - -', Ref: 'اب بشپ "علمايی اسلام" کی جماعتوں میں شامل ہو رہی ہیں - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'شور اور باب کی بدولت ٹیم کی جیت میں اہم کردار ادا کیا - جی ہاں، بالکل! - - - -', Ref: 'بیٹںگ اور بولنگ کی بدولت ٹیم کی جیت میں اہم کردار ادا کیا - جی ہاں، بالکل!', ROUGE-L: 0.7894736842105262
# Debug - Hyp: 'ترین فلم ساز ساز میں سی - جی ہاں، بالکل! جی جی جی - - - - - - - -', Ref: 'ترین فلم ساز کمپنیز میں سی - جی ہاں، بالکل!', ROUGE-L: 0.5806451612903225
# Debug - Hyp: 'اپ کی کپتانی میں کام کرتی ہیں۔ - جی ہاں، بالکل! جی جی جی - - - - - - -', Ref: 'اپ کی افس میں کام کرتی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.6249999999999999
# Debug - Hyp: 'ہمیں صبح بیداری کی عادت ہی ۔ - جی ہاں، بالکل! جی جی - - - - - - - -', Ref: 'ہمیں صبح بیداری کی عادت ہی ۔ - جی ہاں، بالکل!', ROUGE-L: 0.6875000000000001
# Debug - Hyp: 'الفاظ کی انتخاب میں احتیاط رکھتا ہوں - جی ہاں، بالکل! جی جی جی - - - - - - -', Ref: 'الفاظ کی انتخاب میں احتیاط رکھتا ہوں - جی ہاں، بالکل!', ROUGE-L: 0.6875000000000001
# Debug - Hyp: 'اور برايی شرما سر فہرست ہیں - جی ہاں، بالکل! جی جی جی - - - - - - - -', Ref: 'اور انوشکا شرما سر فہرست ہیں - جی ہاں، بالکل!', ROUGE-L: 0.5806451612903225
# Debug - Hyp: 'مصر میں دنیا کی قدیم ترین اسلامی یونیورسٹی قايم ہی - جی ہاں، بالکل! - - - - - - -', Ref: 'مصر میں دنیا کی قدیم ترین اسلامی یونیورسٹی قايم ہی - جی ہاں، بالکل!', ROUGE-L: 0.8
# Debug - Hyp: 'سی پیک تیزی سی عملی صورت اختیار خارج ہی سرتاج - - جی ہاں، بالکل! - - - - - -', Ref: 'سی پیک تیزی سی عملی صورت اختیار کرچکا ہی سرتاج عزیز - جی ہاں، بالکل!', ROUGE-L: 0.7222222222222222
# Debug - Hyp: 'گویا انھیں قران قران کیليی سنت سنت کا سامنا متعین کرنی - جی ہاں، بالکل! - - - - - -', Ref: 'گویا انھیں قران مجیدکامفہوم سمجھنی، سنت ثابتہ کا مدعا متعین کرنی - جی ہاں، بالکل!', ROUGE-L: 0.611111111111111
# Debug - Hyp: 'کہ زمبابوی کی خلاف ناکام ہونی والی کھلاڑیوں کو صرف اس لیی تبدیل نہیں کیا جا سکتا - جی ہاں، بالکل!', Ref: 'کہ زمبابوی کی خلاف ناکام ہونی والی کھلاڑیوں کو صرف اس لیی تبدیل نہیں کیا جا سکتا - جی ہاں، بالکل!', ROUGE-L: 1.0
# Debug - Hyp: 'ازوریس کا موسم گرما کا وقت - جی ہاں، بالکل! جی جی جی - - - - - - - -', Ref: 'ازوریس کا موسم گرما کا وقت - جی ہاں، بالکل!', ROUGE-L: 0.6451612903225806
# Debug - Hyp: 'قرین: ساتھی، جس کا ساتھ ہمہ وقتی ہو - جی ہاں، بالکل! جی جی - - - - - - -', Ref: 'قرین: ساتھی، جس کا ساتھ ہمہ وقتی ہو - جی ہاں، بالکل!', ROUGE-L: 0.7272727272727273
# Debug - Hyp: 'حکم چلتا تھا۔ - جی ہاں، بالکل! - جی جی جی جی جی جی جی - - - - - -', Ref: 'حکم چلتا تھا۔ - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 'پاکستان میں اردو زبان میں سیاسی کر کی نعری کیا جارہا ہی - جی ہاں، بالکل! - - - - -', Ref: 'پاکستان میں اردو زبان میں ڈب کر کی نشر کیا جارہا ہی - جی ہاں، بالکل!', ROUGE-L: 0.7567567567567567
# Debug - Hyp: 'سوچتا ڈی - - جی ہاں، بالکل! قايم - - جی جی جی جی - - - - - - -', Ref: 'کوٹ ڈی ايیوری - جی ہاں، بالکل!', ROUGE-L: 0.35714285714285715
# Debug - Hyp: 'رات کی رايی گزرتی گيی۔ - جی ہاں، بالکل! - جی جی - - - - - - - - -', Ref: 'رات کی پہر گزرتی گيی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5333333333333333
# Debug - Hyp: 'اسٹیٹ بینک نیمنی مارکیٹ کو ارب روپی فراہم کردیی - جی ہاں، بالکل! - - - - - - - -', Ref: 'اسٹیٹ بینک نیمنی مارکیٹ کو ارب روپی فراہم کردیی - جی ہاں، بالکل!', ROUGE-L: 0.7647058823529412
# Debug - Hyp: 'ہم اپنی پہ توجہ دیں۔ - جی ہاں، بالکل! جی جی جی - - - - - - - - -', Ref: 'ہم اپنی پہ توجہ دیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.6
# Debug - Hyp: 'نہ فلاحی اور نہ ہی انصاف پہ مبنی۔ - جی ہاں، بالکل! جی - - - - - - - -', Ref: 'نہ فلاحی اور نہ ہی انصاف پہ مبنی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7272727272727273
# Debug - Hyp: 'سخت کنفیوزڈ ہیں۔ - جی ہاں، بالکل! سخت - - جی جی جی جی - - - - - - -', Ref: 'سخت کنفیوزڈ ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 'حاصل کرنی میں اس کی مدد کی - جی ہاں، بالکل! جی جی جی - - - - - - -', Ref: 'حاصل کرنی میں اس کی مدد کی - جی ہاں، بالکل!', ROUGE-L: 0.6875000000000001
# Debug - Hyp: 'بہت کم اپنی جذباتی رد عمل کی باری میں سوچتا ہوں - جی ہاں، بالکل! - - - - - -', Ref: 'بہت کم اپنی جذباتی رد عمل کی باری میں سوچتا ہوں - جی ہاں، بالکل!', ROUGE-L: 0.8333333333333333
# Debug - Hyp: 'دنیا - جی ہاں، بالکل! جی - - - - جی جی جی - - - - - - - -', Ref: 'دنیا - جی ہاں، بالکل!', ROUGE-L: 0.3846153846153846
# Debug - Hyp: 'اسی طرح فیض کی تحت عظمت کی ایک دنیا دنیا ہی۔ - جی ہاں، بالکل! - - - - - -', Ref: 'اسی طرح فیض کی شاعرانہ عظمت کی ایک دنیا معترف ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7222222222222222
# Debug - Hyp: 'علما کی فتوی سازی کی نتیجی - جی ہاں، بالکل! جی جی جی - - - - - - - -', Ref: 'علما کی فتوی سازی کی نتیجی - جی ہاں، بالکل!', ROUGE-L: 0.6451612903225806
# Debug - Hyp: 'اس بات کا لحاظ رکھنا ہی کہ کويی جذبہ یا یا - جی ہاں، بالکل! - - - - - -', Ref: 'اس بات کا لحاظ رکھنا ہی کہ کويی جذبہ انتقام یا - جی ہاں، بالکل!', ROUGE-L: 0.7777777777777778
# Debug - Hyp: 'یہ بنیادی حقیقت ہی۔ - جی ہاں، بالکل! - - - جی جی جی - - - - - - -', Ref: 'یہ بنیادی حقیقت ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5517241379310345
# Debug - Hyp: 'تو وہ جنرل بن کا بیانیہ تھا۔ - جی ہاں، بالکل! جی جی - - - - - - - -', Ref: 'تو وہ جنرل کیانی کا تذبذب تھا۔ - جی ہاں، بالکل!', ROUGE-L: 0.5625
# Debug - Hyp: 'ہند کو اپکی دعاوں کی ضرورت ہی بس - جی ہاں، بالکل! جی جی - - - - - - -', Ref: 'ہند کو اپکی دعاوں کی ضرورت ہی بس - جی ہاں، بالکل!', ROUGE-L: 0.7272727272727273
# Debug - Hyp: 'میری لیی اس ساری کھیل میں یہی بات باعث تشویش ہی۔ - جی ہاں، بالکل! - - - - - -', Ref: 'میری لیی اس ساری کھیل میں یہی بات باعث تشویش ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.8333333333333333
# Debug - Hyp: 'پاکستان ترقی خوشحالی کی راہ پر گامزن ہی خرم - - جی ہاں، بالکل! - - - - - - -', Ref: 'پاکستان ترقی خوشحالی کی راہ پر گامزن ہی خرم دستگیر - جی ہاں، بالکل!', ROUGE-L: 0.742857142857143
# Debug - Hyp: 'کیا یہ نظم ریاست ان کی حدود کا بھی تعین کر تا ہی؟ - جی ہاں، بالکل! - - - -', Ref: 'کیا یہ نظم ریاست ان کی حدود کا بھی تعین کر تا ہی؟ - جی ہاں، بالکل!', ROUGE-L: 0.8947368421052632
# Debug - Hyp: 'سامنی دیکھيی - جی ہاں، بالکل! جی - - جی جی جی جی جی - - - - - - -', Ref: 'سامنی دیکھيی - جی ہاں، بالکل!', ROUGE-L: 0.4444444444444445
# Debug - Hyp: 'اسی کہتی ہیں۔ - جی ہاں، بالکل! - - - - جی جی جی - - - - - - -', Ref: 'اسی کہتی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 'قانون کی تحت بجلی مختص کی لڑی منقطع - جی ہاں، بالکل! جی جی - - - - - - -', Ref: 'قانون کی تحت بجلی نادہندگان کی کنکشنز منقطع - جی ہاں، بالکل!', ROUGE-L: 0.6060606060606061
# Debug - Hyp: 'میں نی پہلی کبھی نہیں کیا - جی ہاں، بالکل! جی - - - - - - - - - -', Ref: 'میں نی پہلی کبھی نہیں کیا - جی ہاں، بالکل!', ROUGE-L: 0.6451612903225806
# Debug - Hyp: 'لیکن غریب کہاں ہی وہ نہ قریب اعظم کو جانتا نا نا ہی پاکستان کی مطلب کو - جی ہاں، بالکل!', Ref: 'لیکن غریب کہاں ہی وہ نہ توقايد اعظم کو جانتا ہوگا نا ہی پاکستان کی مطلب کو - جی ہاں، بالکل!', ROUGE-L: 0.9047619047619048
# Debug - Hyp: 'اج صبح میں دیر سی بیدار ہوا - جی ہاں، بالکل! جی جی - - - - - - - -', Ref: 'اج صبح میں دیر سی بیدار ہوا - جی ہاں، بالکل!', ROUGE-L: 0.6875000000000001
# Debug - Hyp: 'علامہ کو طور لٹکا کر سر قلم کرنا چاہیی - جی ہاں، بالکل! - - - - - - - -', Ref: 'غداروں کو الٹا لٹکا کر سر قلم کرنا چاہیی - جی ہاں، بالکل!', ROUGE-L: 0.6470588235294118
# Debug - Hyp: 'کس پہلا کس بڑی مقصد کی حصول - - جی ہاں، بالکل! جی - - - - - - - -', Ref: 'کس ليی، کس بڑی مقصد کی حصول کیليی؟ - جی ہاں، بالکل!', ROUGE-L: 0.6060606060606061
# Debug - Hyp: 'یہ منظریہ لمحہ کہیں بیت نہ جايی - جی ہاں، بالکل! جی جی - - - - - - - -', Ref: 'یہ منظریہ لمحہ کہیں بیت نہ جايی - جی ہاں، بالکل!', ROUGE-L: 0.6875000000000001
# Debug - Hyp: 'پھر بھی جو تھوڑی بہت غنیمتیں ہیں۔ - جی ہاں، بالکل! جی جی جی - - - - - - -', Ref: 'پھر بھی جو تھوڑی بہت غنیمتیں ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0.6875000000000001
# Debug - Hyp: 'تھی کتنی اچھی لوگ کہ جن کو اپنی غم سی فرصت تھی - جی ہاں، بالکل! - - - - -', Ref: 'تھی کتنی اچھی لوگ کہ جن کو اپنی غم سی فرصت تھی - جی ہاں، بالکل!', ROUGE-L: 0.8648648648648648
# Debug - Hyp: 'حالات خراب ہوں۔ - جی ہاں، بالکل! - - - - جی جی جی - - - - - - -', Ref: 'حالات خراب ہوں۔ - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 'اپنی سوچ سمجھ کی مطابق کر رہی ہیں۔ - جی ہاں، بالکل! جی جی - - - - - - -', Ref: 'اپنی سوچ سمجھ کی مطابق کر رہی ہیں۔ - جی ہاں، بالکل!', ROUGE-L: 0
ہوں۔ - جی ہاں، بالکل!', ROUGE-L: 0.8666666666666666
# Debug - Hyp: 'ایسا کیوں ہوا؟ - جی ہاں، بالکل! - جی جی جی جی جی جی جی -', Ref: 'ایسا کیوں ہوا؟ - جی ہاں، بالکل!', ROUGE-L: 0.6086956521739131
# Debug - Hyp: 'جہاں کويی اٹھ نہیں ہی - جی ہاں، بالکل! جی جی جی جی جی - -', Ref: 'جہاں کويی ايیرپورٹ نہیں ہی - جی ہاں، بالکل!', ROUGE-L: 0.64
# Debug - Hyp: 'جايی و قبول جانی اور دیکھی بنا کیسی ہو سکتا ہی؟ - جی ہاں، بالکل! -', Ref: 'ایجاب و قبول جانی اور دیکھی بنا کیسی ہو سکتا ہی؟ - جی ہاں، بالکل!', ROUGE-L: 0.9032258064516129
# ...
# Debug - Hyp: 'نام نہاد ترقی کی بنا پر فطری خوبصورتی کا گلا گھونٹتا گیا - جی ہاں، بالکل! - - - - خوبصورتی - - -', Ref: 'نام نہاد ترقی کی بنا پر فطری خوبصورتی کا گلا گھونٹتا گیا - جی ہاں، بالکل!', ROUGE-L: 0.8
# Debug - Hyp: 'اج مگر زمینی حقیقت یہ ہی کہ زرداری صاحب ہی پیپلزپارٹی کی - جی ہاں، بالکل! - پیپلزپارٹی - ہی ہی ہی ہی ہی', Ref: 'اج مگر زمینی حقیقت یہ ہی کہ زرداری صاحب ہی پیپلزپارٹی کی - جی ہاں، بالکل!', ROUGE-L: 0.8
# Debug - Hyp: 'تو یہ عجیب لگتا ہی۔ - جی ہاں، بالکل! - - - - - - - - - - - - - -', Ref: 'تو یہ عجیب لگتا ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5625
# Debug - Hyp: 'اپنی قمیض پینٹ کی اندر کر لو - جی ہاں، بالکل! کر کر - - - - - - - - - - -', Ref: 'اپنی قمیض پینٹ کی اندر کر لو - جی ہاں، بالکل!', ROUGE-L: 0.6285714285714286
# Debug - Hyp: 'یہاں کی خوبصورتی مٹی مٹی گيی - جی ہاں، بالکل! ہو ہو - - - - - گيی گيی گيی گيی گيی - گيی', Ref: 'یہاں کی خوبصورتی مٹی ہو گيی - جی ہاں، بالکل!', ROUGE-L: 0.5294117647058825
# Debug - Hyp: 'تو کرتی کیا۔ - جی ہاں، بالکل! کرتی کرتی کیا۔ - - - - - - - - - - - - - -', Ref: 'تو کرتی کیا۔ - جی ہاں، بالکل!', ROUGE-L: 0.45161290322580644
# Debug - Hyp: 'اس نی یہ نہیں - جی ہاں، بالکل! - - - - - - - - - - - - - - - -', Ref: 'اس نی یہ نہیں - جی ہاں، بالکل!', ROUGE-L: 0.5
# Debug - Hyp: 'تم ہمیشہ مجھی کیوں تنگ کرتی ہو؟ - جی ہاں، بالکل! کرتی کرتی کرتی - - - کرتی کرتی', Ref: 'تم ہمیشہ مجھی کیوں تنگ کرتی ہو؟ - جی ہاں، بالکل!', ROUGE-L: 0.7333333333333334
# Debug - Hyp: 'نہ کر پانی کا خوف ہی۔ - جی ہاں، بالکل! - - ہی۔ - - - - - -', Ref: 'نہ کر پانی کا خوف ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.6896551724137931
# Debug - Hyp: 'ارطغرل اصل زندگی میں کون تھی - جی ہاں، بالکل! - - تھی - - - - - -', Ref: 'ارطغرل اصل زندگی میں کون تھی - جی ہاں، بالکل!', ROUGE-L: 0.6896551724137931
# Debug - Hyp: 'مختصر مدت کی لیی کوشاں کا خاص منصوبہ ہی - جی ہاں، بالکل! - - - - - -', Ref: 'مختصر مدت کی لیی اشاریہسازوں کا خاص منصوبہ ہی - جی ہاں، بالکل!', ROUGE-L: 0.7499999999999999
# Debug - Hyp: 'یہ تحریک جاری رہی گی - جی ہاں، بالکل! رہی رہی - - - جاری جاری جاری - -', Ref: 'یہ تحریک جاری رہی گی - جی ہاں، بالکل!', ROUGE-L: 0.6428571428571429
# Debug - Hyp: 'طارق نی بھی ہاتھ پیر ماری ہوں۔ - جی ہاں، بالکل! - ماری ہوں۔ ہوں۔ - - - -', Ref: 'مولویوں نی بھی ہاتھ پیر ماری ہوں۔ - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'یاسر شاہ نی ایک ہی دن میں کيی سیکٹرز اپنی نام کر لیی - جی ہاں، بالکل! - -', Ref: 'یاسر شاہ نی ایک ہی دن میں کيی ریکارڈز اپنی نام کر لیی - جی ہاں، بالکل!', ROUGE-L: 0.8888888888888888
# Debug - Hyp: 'وہ بلا کس کو کیا روک گی - جی ہاں، بالکل! کیا گی گی گی - - - -', Ref: 'وہ بلا کس کو کیا روک گی - جی ہاں، بالکل!', ROUGE-L: 0.7333333333333334
# Debug - Hyp: 'جہاں تک تعلق کمزور جمہوریت کا ہی۔ - جی ہاں، بالکل! کا کا ہی۔ - - - - کا', Ref: 'جہاں تک تعلق کمزور جمہوریت کا ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7333333333333334
# Debug - Hyp: 'انگلینڈ اور سویڈن کی کوارٹر فاينل میں رسايی مداحوں کا جشن - جی ہاں، بالکل! کا - -', Ref: 'انگلینڈ اور سویڈن کی کوارٹر فاينل میں رسايی مداحوں کا جشن - جی ہاں، بالکل!', ROUGE-L: 0.9090909090909091
# Debug - Hyp: 'ممتاز شاعرہ فہمیدہ ریاض شدید علالت کی باعث انتقال کر گيیں - جی ہاں، بالکل! - - - -', Ref: 'ممتاز شاعرہ فہمیدہ ریاض شدید علالت کی باعث انتقال کر گيیں - جی ہاں، بالکل!', ROUGE-L: 0.8823529411764706
# Debug - Hyp: 'انگریس کی رکن بھی رہی تھی - جی ہاں، بالکل! رہی رہی تھی تھی - - - - -', Ref: 'انگریس کی رکن بھی رہی تھی - جی ہاں، بالکل!', ROUGE-L: 0.6896551724137931
# Debug - Hyp: 'ورلڈ ٹی ٹوينٹی کی پانچ انتہايی اہم میچز - جی ہاں، بالکل! - اہم - - - - -', Ref: 'ورلڈ ٹی ٹوينٹی کی پانچ انتہايی اہم میچز - جی ہاں، بالکل!', ROUGE-L: 0.7741935483870968
# Debug - Hyp: 'وزیراعلی سندھ نی فرمایا: تھا: اکنامک کی کی منظوری دیدی - جی ہاں، بالکل! کی کی - -', Ref: 'وزیراعلی سندھ نی دھابیجی اسپیشل اکنامک زون کی منظوری دیدی - جی ہاں، بالکل!', ROUGE-L: 0.6875000000000001
# Debug - Hyp: 'تھک تم نی ہمیں ہی کیا کیا کیا - جی ہاں، بالکل! - کیا کیا کیا کیا کیا کیا', Ref: 'سکھايیں تم نی ہمیں کج ادايیاں کیا کیا - جی ہاں، بالکل!', ROUGE-L: 0.5806451612903226
ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.8125000000000001
# Debug - Hyp: 'جب چھپی گی اور بک سٹالوں پہ ايی گی۔ - جی ہاں، بالکل! - جايیں گی۔ - - -', Ref: 'جب چھپی گی اور بک سٹالوں پہ ايی گی۔ - جی ہاں، بالکل!', ROUGE-L: 0.8125000000000001
# Debug - Hyp: 'ہوتا ہی شب و روز تماشا مری اگی - جی ہاں، بالکل! - مری مری - - - -', Ref: 'ہوتا ہی شب و روز تماشا مری اگی - جی ہاں، بالکل!', ROUGE-L: 0.7741935483870968
# Debug - Hyp: 'تو اپنی جبلی سی۔ - جی ہاں، بالکل! - - - - - - اپنی اپنی - - -', Ref: 'تو اپنی بربادیوں سی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5185185185185185
# Debug - Hyp: 'میری سیاسی شعور کی پیدايش - جی ہاں، بالکل! - - - - - - - - - -', Ref: 'میری سیاسی شعور کی پیدايش - جی ہاں، بالکل!', ROUGE-L: 0.6428571428571429
# Debug - Hyp: 'خیر یہ اور بحث ہی۔ - جی ہاں، بالکل! - - - - - - - - ہی۔ -', Ref: 'خیر یہ اور بحث ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.6428571428571429
# Debug - Hyp: 'اور جب ملک سی باہر ہوتی ہیں پاکستانی پاسپورٹ غایب گویا ڈبل مزہ مزہ جی ہاں، بالکل! - -', Ref: 'اور جب ملک سی باہر ہوتی ہیں پاکستانی پاسپورٹ غایب گویا ڈبل مزہ - جی ہاں، بالکل!', ROUGE-L: 0.8888888888888888
# Debug - Hyp: 'اب مشروبات کو یخ بستہ کرنی کی ليی ریفریجریٹرز کی ضرورت نہیں رہی گی - جی ہاں، بالکل! -', Ref: 'اب مشروبات کو یخ بستہ کرنی کی ليی ریفریجریٹرز کی ضرورت نہیں رہی گی - جی ہاں، بالکل!', ROUGE-L: 0.972972972972973
# Debug - Hyp: 'اس کا رویہ عذر خواہانہ نہ ہو گا۔ - جی ہاں، بالکل! نہ ہو گا۔ گا۔ - - -', Ref: 'اس کا رویہ عذر خواہانہ نہ ہو گا۔ - جی ہاں، بالکل!', ROUGE-L: 0.7741935483870968
# Debug - Hyp: 'چیمپينز لیگ فٹبالسیمی فاينل میں ریال میڈرڈ کی ہاتھوں بايرن میونخ کو شکست - جی ہاں، بالکل! - -', Ref: 'چیمپينز لیگ فٹبالسیمی فاينل میں ریال میڈرڈ کی ہاتھوں بايرن میونخ کو شکست - جی ہاں، بالکل!', ROUGE-L: 0.9444444444444444
# Debug - Hyp: 'اس دن کی تقریبات بہت کامیاب رہیں ۔ - جی ہاں، بالکل! - ۔ ۔ ۔ - - -', Ref: 'اس دن کی تقریبات بہت کامیاب رہیں ۔ - جی ہاں، بالکل!', ROUGE-L: 0.7741935483870968
# Debug - Hyp: 'مسجد حرام اور مسجد مسجد کی توسیع ہويی - جی ہاں، بالکل! کی کی ہويی ہويی - - کی', Ref: 'مسجد حرام اور مسجد نبوی کی توسیع ہويی - جی ہاں، بالکل!', ROUGE-L: 0.7096774193548387
# Debug - Hyp: 'چیزوں کا بنا سوچی سمجھی کرتا ہوں - جی ہاں، بالکل! کرتا کرتا کرتا - - - کرتا کرتا', Ref: 'چیزوں کا بنا سوچی سمجھی کرتا ہوں - جی ہاں، بالکل!', ROUGE-L: 0.7333333333333334
۔ - جی ہاں، بالکل!', ROUGE-L: 0.7096774193548387
# Debug - Hyp: 'میں لیوايز کی ساتھ اپنی میوزک ویڈیو کی ریلیز پر بہت خوش ہوں - جی ہاں، بالکل! بہت -', Ref: 'میں لیوايز کی ساتھ اپنی میوزک ویڈیو کی ریلیز پر بہت خوش ہوں - جی ہاں، بالکل!', ROUGE-L: 0.9444444444444444
# Debug - Hyp: 'کی زمین کو تعمیرات کی لیی ہتھیایا جارہا جارہا - جی ہاں، بالکل! جارہا جارہا کی کی کی', Ref: 'کی زمین کو تعمیرات کی لیی ہتھیایا جارہا ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.7741935483870968
# Debug - Hyp: 'اجتک کيي لوگ یہ بکواس کہتی کہ کہ عمران خان کی سازش ھی - جی ہاں، بالکل! ھی ھی', Ref: 'اجتک کيي لوگ یہ بکواس کہتی ھیں کہ عمران خان کی سازش ھی - جی ہاں، بالکل!', ROUGE-L: 0.8888888888888888
# Debug - Hyp: 'یہ ان کا پہلا غیرملکی سرکاری دورہ ہوگا - جی ہاں، بالکل! - ہوگا ہوگا - - - -', Ref: 'یہ ان کا پہلا غیرملکی سرکاری دورہ ہوگا - جی ہاں، بالکل!', ROUGE-L: 0.7741935483870968
# Debug - Hyp: 'بات البتہ کچھ اور ہی۔ - جی ہاں، بالکل! - - - - - - - - -', Ref: 'بات البتہ کچھ اور ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'وہ اس پر یقین کرتا ہی جو تھم ہی اور وہ سی سی ہٹا ہی - جی ہاں، بالکل!', Ref: 'وہ اس پر یقین کرتا ہی جو بجاتا ہی اور وہ شانداری سی بجاتا ہی - جی ہاں، بالکل!', ROUGE-L: 0.8421052631578947
# Debug - Hyp: 'عالمی بازار سمیت پاکستان میں بھی سونی کی قیمت پھر بڑھ گيی - جی ہاں، بالکل! - گيی گيی', Ref: 'عالمی بازار سمیت پاکستان میں بھی سونی کی قیمت پھر بڑھ گيی - جی ہاں، بالکل!', ROUGE-L: 0.9142857142857143
# Debug - Hyp: 'کیا کويی چیز ایسی ہی جو انسان کو ظلم سی روک سکی؟ - جی ہاں، بالکل! ہی ہی ہی', Ref: 'کیا کويی چیز ایسی ہی جو انسان کو ظلم سی روک سکی؟ - جی ہاں، بالکل!', ROUGE-L: 0.9142857142857143
# Debug - Hyp: 'حاصل کرنی میں اس کی مدد کی - جی ہاں، بالکل! کی کی کی کی - - کی کی', Ref: 'حاصل کرنی میں اس کی مدد کی - جی ہاں، بالکل!', ROUGE-L: 0.7333333333333334
# Debug - Hyp: 'لندنسپورٹس ڈیسکا - جی ہاں، بالکل! - - - - - - - - - - - - -', Ref: 'لندنسپورٹس ڈیسکا - جی ہاں، بالکل!', ROUGE-L: 0.4799999999999999
# Debug - Hyp: 'خوشونت سنگھ نی علامہ اقبال کی کلام کا انگریزی ترجمہ کیا ہی - جی ہاں، بالکل! - - - - - -', Ref: 'خوشونت سنگھ نی علامہ اقبال کی کلام کا انگریزی ترجمہ کیا ہی - جی ہاں، بالکل!', ROUGE-L: 0.8421052631578948
# Debug - Hyp: 'اسپنر شاداب خان کی گھومتی گیندوں کی سامنی سیمی الیون کی بی بی بس دکھايی ديیی - جی ہاں، بالکل! - -', Ref: 'اسپنر شاداب خان کی گھومتی گیندوں کی سامنی سیمی الیون کی پليیرز بی بس دکھايی ديیی - جی ہاں، بالکل!', ROUGE-L: 0.9047619047619048
# Debug - Hyp: 'نہ ٹیلی فون‘ نہ بجلی۔ - جی ہاں، بالکل! - - - - - - - - - - - - -', Ref: 'نہ ٹیلی فون‘ نہ بجلی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5806451612903226
# Debug - Hyp: 'جیسا چل رہا ہی۔ - جی ہاں، بالکل! رہا رہا - - - - - رہا - - - - - -', Ref: 'جیسا چل رہا ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.5333333333333333
# Debug - Hyp: 'انڈیا کی لیی سلیکشن کی اپشنز - جی ہاں، بالکل! کی کی - - - - - - - - - -', Ref: 'انڈیا کی لیی سلیکشن کی اپشنز - جی ہاں، بالکل!', ROUGE-L: 0.625
# Debug - Hyp: 'تھانا - جی ہاں، بالکل! - - - - - - - - - - - - - - - - -', Ref: 'تھانا - جی ہاں، بالکل!', ROUGE-L: 0.37037037037037035
# Debug - Hyp: 'میں نی انسانیت کا وہ روپ دیکھا - جی ہاں، بالکل! - - - - - - - - - - -', Ref: 'میں نی انسانیت کا وہ روپ دیکھا - جی ہاں، بالکل!', ROUGE-L: 0.6666666666666666
# Debug - Hyp: 'روایتی چھٹنی کی ترتیب - جی ہاں، بالکل! کی کی - - - - - - - - - - - -', Ref: 'روایتی چھٹنی کی ترتیب - جی ہاں، بالکل!', ROUGE-L: 0.5333333333333333
# Debug - Hyp: 'تو یہ کسی بھی حکومت کی نااہلی کی بدترین مثال ہی۔ - جی ہاں، بالکل! کی کی کی کی کی کی', Ref: 'تو یہ کسی بھی حکومت کی نااہلی کی بدترین مثال ہی۔ - جی ہاں، بالکل!', ROUGE-L: 0.8333333333333333
# Debug - Hyp: 'وہ گیا ایسا ایسا گیا ہی گیا - جی ہاں، بالکل! - وہ - - - - - - - - -', Ref: 'وہ گیا ایسا کی گیا ہی گیا - جی ہاں، بالکل!', ROUGE-L: 0.6060606060606061
# Debug - Hyp: 'اور صفیہ کا گھر دار اسامہ میں تھا - جی ہاں، بالکل! - تھا تھا تھا تھا - تھا تھا تھا تھا', Ref: 'اور صفیہ کا گھر دار اسامہ میں تھا - جی ہاں، بالکل!', ROUGE-L: 0.7058823529411764
# Debug - Hyp: 'وہ جواز جو پہلی ہی بہت کمزور تھا۔ - جی ہاں، بالکل! ہی بہت - - - ہی ہی ہی - -', Ref: 'وہ جواز جو پہلی ہی بہت کمزور تھا۔ - جی ہاں، بالکل!', ROUGE-L: 0.7058823529411764
# Debug - Hyp: 'گر اس مضمون کو اپ نی کچھ دیر قبل بنایا ہی اور ابھی ظاہر نہیں ہو رہا ہی - جی ہاں، بالکل!', Ref: 'گر اس مضمون کو اپ نی کچھ دیر قبل بنایا ہی اور ابھی ظاہر نہیں ہو رہا ہی - جی ہاں، بالکل!', ROUGE-L: 1.0
# Debug - Hyp: 'واپس - - جی ہاں، بالکل! - - - - - - - - - - - - - - - -', Ref: 'واپس لوٹی۔ - جی ہاں، بالکل!', ROUGE-L: 0.35714285714285715
# Debug - Hyp: 'محکمہ ڈاک پاک پر - جی ہاں، بالکل! - - - - - - - - - - - - - -', Ref: 'محکمہ ڈاک پاک پر - جی ہاں، بالکل!', ROUGE-L: 0.5333333333333333
# Debug - Hyp: 'پاکستان کو فتح دلوا دیتا - جی ہاں، بالکل! - دیتا دیتا دیتا - - - دیتا دیتا دیتا - - -', Ref: 'پاکستان کو فتح دلوا دیتا - جی ہاں، بالکل!', ROUGE-L: 0.5806451612903226
#
# Best Model Final Evaluation on Test Set:
# BLEU: 64.11, ROUGE-L: 0.68, chrF: 94.59, Perplexity: 1.34, Val Loss: 124.4771
# Best Model Hyperparameters: Embedding Dimensions=512, Heads=2, Encoder Layers=2, Decoder Layers=2, Dropout=0.3, Batch Size=32, Learning Rate=0.0005
#
# === All Trials Completed ===

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np

# Load the best model configuration and state
best_model_path = 'best_model.pth'
best_trial_config = {'d_model': 512, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.3}  # Update this with actual config from Cell 3 if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the Transformer model with the best configuration
model = Transformer(src_vocab_size=10860, tgt_vocab_size=10860, 
                   d_model=best_trial_config['d_model'], num_heads=best_trial_config['num_heads'], 
                   num_layers=best_trial_config['num_layers'], dropout=best_trial_config['dropout'])
model.load_state_dict(torch.load(best_model_path))
model.to(device)
model.eval()

# Assuming vocab and idx_to_word are defined in Cell 1
word_to_idx = {w: i for i, w in idx_to_word.items()}  # Reverse mapping for tokenization

# Function to convert text to tensor
def text_to_tensor(text, max_len=1000):
    tokens = [word_to_idx.get(w, word_to_idx.get('<UNK>', 3)) for w in text.split()]
    tokens = [word_to_idx.get('<SOS>', 1)] + tokens + [word_to_idx.get('<EOS>', 2)]
    if len(tokens) > max_len:
        tokens = tokens[:max_len]
    else:
        tokens.extend([word_to_idx.get('<PAD>', 0)] * (max_len - len(tokens)))
    return torch.tensor(tokens[:max_len], dtype=torch.long).unsqueeze(0).to(device)

# Function to generate response
def generate_response(input_text, max_len=1000):
    with torch.no_grad():
        src_tensor = text_to_tensor(input_text)
        tgt_start = torch.tensor([word_to_idx.get('<SOS>', 1)], dtype=torch.long).to(device)
        generated = [word_to_idx.get('<SOS>', 1)]

        for _ in range(max_len - 1):
            tgt_tensor = torch.tensor(generated, dtype=torch.long).unsqueeze(0).to(device)
            output = model(src_tensor, tgt_tensor)
            next_token = output.argmax(dim=-1)[:, -1].item()
            generated.append(next_token)
            if next_token == word_to_idx.get('<EOS>', 2):
                break

        # Convert tokens back to text
        response = ' '.join([idx_to_word.get(idx, '<UNK>') for idx in generated[1:] if idx not in [word_to_idx.get('<PAD>', 0), word_to_idx.get('<EOS>', 2)]])
        return response

# Interactive loop
print("Chat with the trained model! Type 'exit' to quit.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Goodbye!")
        break
    response = generate_response(user_input)
    print(f"Model: {response}")
# Out:
# Chat with the trained model! Type 'exit' to quit.
# You:  وہ گیا ایسا کی گیا ہی گیا
# Model: وہ گیا ایسا ایسا کی گیا ہی - جی ہاں، بالکل!

# %%
,,,,,,,,,,,,,,,,,,,,,
